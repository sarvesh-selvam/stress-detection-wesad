# %% [markdown]
# # Feature Extraction
#
# This notebook extracts statistical and signal-based features from the preprocessed ECG, EDA, and Resp. signals for each subject, and compiles them into a structured Pandas DataFrame for model development.

# %%
# Importing Dependencies

import numpy as np
import pandas as pd
from pathlib import Path

from scipy.signal import find_peaks

# Project root (one level up from notebooks/)
BASE_DIR = Path("..").resolve()

# Disable UserWarnings
import warnings
warnings.filterwarnings("ignore", category=UserWarning)

# %%
# Load one subject's processed data

X = np.load(BASE_DIR / "data/processed/S4_segments.npy")
y = np.load(BASE_DIR / "data/processed/S4_labels.npy")

print("X shape:", X.shape)
print("y shape:", y.shape)

# %% [markdown]
# ## Functions for Extracting Features

# %%
def extract_ecg_features(signal, fs=700):
    # Height threshold at 75th percentile filters noise while preserving R-peaks
    height_threshold = np.percentile(signal, 75)
    peaks, _ = find_peaks(signal, distance=int(fs * 0.5), height=height_threshold)
    rr_intervals = np.diff(peaks) / fs  # seconds between beats

    return {
        "mean_rr": np.mean(rr_intervals) if len(rr_intervals) > 0 else 0,
        "sdnn": np.std(rr_intervals) if len(rr_intervals) > 0 else 0,
        "rmssd": np.sqrt(np.mean(np.square(np.diff(rr_intervals)))) if len(rr_intervals) > 1 else 0,
        "ecg_peak_count": len(peaks)
    }


def extract_eda_features(signal):
    peaks, _ = find_peaks(signal, distance=100)
    slope = (signal[-1] - signal[0]) / len(signal)

    return {
        "eda_mean": np.mean(signal),
        "eda_std": np.std(signal),
        "eda_peak_count": len(peaks),
        "eda_slope": slope
    }


def extract_resp_features(signal):
    zero_crossings = np.sum(np.diff(np.sign(signal)) != 0)

    return {
        "resp_mean": np.mean(signal),
        "resp_std": np.std(signal),
        "resp_zero_crossings": zero_crossings
    }

# %%
features = []

for segment in X:
    ecg = segment[:, 0]
    eda = segment[:, 1]
    resp = segment[:, 2]

    ecg_feats = extract_ecg_features(ecg)
    eda_feats = extract_eda_features(eda)
    resp_feats = extract_resp_features(resp)

    # Combine all into one feature vector
    all_feats = {**ecg_feats, **eda_feats, **resp_feats}
    features.append(list(all_feats.values()))

# %%
feature_names = list(all_feats.keys())  # use the last one to get names
df_features = pd.DataFrame(features, columns=feature_names)
df_features["label"] = y

df_features
# Out:
#       mean_rr      sdnn     rmssd  ecg_peak_count  eda_mean   eda_std  \
# 0    0.843429  0.074989  0.049117              71 -0.564494  0.167938
# 1    0.870525  0.082804  0.056357              69 -0.462671  0.028234
# 2    0.925312  0.079787  0.072495              65 -0.517287  0.049605
# 3    0.931786  0.080734  0.082019              65 -0.572951  0.028220
# 4    0.919643  0.066348  0.065230              65 -0.630440  0.052114
# ..        ...       ...       ...             ...       ...       ...
# 208  0.846898  0.111569  0.085991              71  0.327153  0.015504
# 209  0.880567  0.117375  0.062482              69  0.345581  0.026521
# 210  0.998378  0.075708  0.070412              60  0.372413  0.007476
# 211  0.957604  0.134460  0.071001              63  0.372250  0.006622
# 212  0.828390  0.120060  0.053736              72  0.356029  0.023216
#
#      eda_peak_count     eda_slope  resp_mean  resp_std  resp_zero_crossings  \
# 0                39  1.386197e-05   0.000487  0.979562                   31
# 1                41  1.066180e-06   0.053279  0.957919                   35
# 2                35 -2.384147e-06   0.000799  0.891410                   37
# 3                32 -2.865320e-06  -0.019642  0.826233                   44
# 4                34 -4.090417e-06  -0.018199  0.750609                   45
# ..              ...           ...        ...       ...                  ...
# 208              35  1.828373e-07  -0.042851  1.484759                   27
# 209              37  1.414749e-06   0.087361  1.123280                   29
# 210              43  2.134597e-07   0.039183  0.906761                   34
# 211              43 -2.375773e-07   0.020059  1.385700                   33
# 212              38 -1.281926e-06  -0.027604  1.596979                   32
#
#      label
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
# ..     ...
# 208      0
# 209      0
# 210      0
# 211      0
# 212      0
#
# [213 rows x 12 columns]

# %%
df_features.label.value_counts()
# Out:
# label
# 0    108
# 1     39
# 4     27
# 2     21
# 3     12
# 5      2
# 7      2
# 6      2
# Name: count, dtype: int64

# %% [markdown]
# ## Looping it Over All Subjects

# %%
subjects = [f"S{i}" for i in range(2, 18) if i != 12]
input_dir = BASE_DIR / "data/processed"
output_dir = BASE_DIR / "data/features"

for subj in subjects:
    try:
        print(f"\n🔄 Extracting features for {subj}...")
        X = np.load(input_dir / f"{subj}_segments.npy")
        y = np.load(input_dir / f"{subj}_labels.npy")

        features = []
        for segment in X:
            ecg = segment[:, 0]
            eda = segment[:, 1]
            resp = segment[:, 2]

            ecg_feats = extract_ecg_features(ecg)
            eda_feats = extract_eda_features(eda)
            resp_feats = extract_resp_features(resp)

            all_feats = {**ecg_feats, **eda_feats, **resp_feats}
            features.append(list(all_feats.values()))

        feature_names = list(all_feats.keys())
        df = pd.DataFrame(features, columns=feature_names)
        df["label"] = y

        df.to_csv(output_dir / f"{subj}_features.csv", index=False)
        print(f"✅ Done: {df.shape[0]} samples saved.")
    except Exception as e:
        print(f"❌ Failed to process {subj}: {e}")
